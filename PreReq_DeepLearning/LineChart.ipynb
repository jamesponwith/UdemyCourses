# %%
import pandas as pd

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7e8b04b90b6f> in <module>()
# ----> 1 t1 = pd.read_csv('table1.csv')
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 10)

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
plt.show()

# %%
x = np.linspace(0, 10, 100)

# %%
y = sin(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1fb2b69a9cfb> in <module>()
# ----> 1 y = sin(x)
#
# NameError: name 'sin' is not defined

# %%
y = np.sin(x)

# %%
plt.show()

# %%
plt.plot(x, y)

# %%
plt.show()
